# %% [markdown]
# # Arquivo feito para rodar o algoritmo para os dados da planilha de validação enviada para a experiente em adoções

# %%
import pandas as pd
import numpy as np

# %%
path_pets = '../DataTables/PetMappedValidation.xlsx'
path_users = '../DataTables/UserMappedValidation.xlsx'
path_database = '../DataTables/Base - ONG.xlsx'

# %%
pets = pd.read_excel(path_pets)
users = pd.read_excel(path_users)
database = users.join(pets)
pets_validacao = pd.read_excel('../DataTables/Pets.xlsx')
pets_validacao = pets_validacao.set_index("Id")
pets_validacao = pets_validacao.drop_duplicates()


lista = [n for n in range(1, len(database) + 1)]
database['idUser'] = lista
database = database.set_index('idUser')

# %%
database.describe()
# Out:
#              age  hadOtherPet  typeOfResidence  hasChildren  \
# count  59.000000    59.000000        59.000000    59.000000
# mean    1.779661     0.711864         0.762712     0.355932
# std     1.260375     0.456782         0.897102     0.482905
# min     0.000000     0.000000         0.000000     0.000000
# 25%     0.000000     0.000000         0.000000     0.000000
# 50%     2.000000     1.000000         0.000000     0.000000
# 75%     3.000000     1.000000         2.000000     1.000000
# max     4.000000     1.000000         2.000000     1.000000
#
#        financialResources  lifestyle   freeTime  adoptionAge  energyLevel  \
# count           59.000000  59.000000  59.000000    59.000000         59.0
# mean             2.457627   0.605932   0.622881     0.155932          0.0
# std              0.566965   0.237640   0.182020     0.216772          0.0
# min              1.000000   0.250000   0.250000     0.000000          0.0
# 25%              2.000000   0.500000   0.500000     0.000000          0.0
# 50%              2.000000   0.750000   0.750000     0.000000          0.0
# 75%              3.000000   0.750000   0.750000     0.300000          0.0
# max              3.000000   1.000000   0.750000     0.700000          0.0
#
#          dogSize  physicalNeeds  temperament  behaviorWithKids  \
# count  59.000000      59.000000    59.000000         59.000000
# mean    0.423729       0.457627     0.805085          0.601695
# std     0.380716       0.325472     0.321861          0.462188
# min     0.000000       0.000000     0.000000          0.000000
# 25%     0.000000       0.250000     0.500000          0.000000
# 50%     0.500000       0.500000     1.000000          1.000000
# 75%     0.500000       0.500000     1.000000          1.000000
# max     1.000000       1.000000     1.000000          1.000000
#
#        behaviorWithAnimals  specialCareNeeds  coatCharacteristics
# count            59.000000         59.000000            59.000000
# mean              0.703390          0.228814             0.466102
# std               0.436667          0.386430             0.403267
# min               0.000000          0.000000             0.000000
# 25%               0.250000          0.000000             0.000000
# 50%               1.000000          0.000000             0.500000
# 75%               1.000000          0.500000             1.000000
# max               1.000000          1.000000             1.000000

# %%
users = database[['age', 'hadOtherPet', 'typeOfResidence', 'hasChildren', 'financialResources', 'lifestyle', 'freeTime']]
pets = database[['adoptionAge', 'energyLevel', 'dogSize', 'physicalNeeds', 'temperament', 'behaviorWithKids', 'behaviorWithAnimals', 
              'specialCareNeeds', 'coatCharacteristics']]

# %%
pets.head()
# Out:
#         adoptionAge  energyLevel  dogSize  physicalNeeds  temperament  \
# idUser
# 1               0.0            0      0.0            0.5          1.0
# 2               0.0            0      0.5            0.5          1.0
# 3               0.0            0      1.0            1.0          1.0
# 4               0.3            0      0.5            0.5          0.5
# 5               0.3            0      0.5            0.0          1.0
#
#         behaviorWithKids  behaviorWithAnimals  specialCareNeeds  \
# idUser
# 1                    1.0                  1.0               0.0
# 2                    0.5                  0.5               0.0
# 3                    1.0                  1.0               0.0
# 4                    0.0                  0.0               0.0
# 5                    1.0                  1.0               0.0
#
#         coatCharacteristics
# idUser
# 1                       0.0
# 2                       0.5
# 3                       0.5
# 4                       1.0
# 5                       1.0

# %%
users.head()
# Out:
#         age  hadOtherPet  typeOfResidence  hasChildren  financialResources  \
# idUser
# 1         0            1                0            0                   3
# 2         0            1                0            0                   3
# 3         0            1                0            0                   3
# 4         0            1                0            0                   3
# 5         3            0                0            0                   3
#
#         lifestyle  freeTime
# idUser
# 1            0.25      0.75
# 2            0.25      0.75
# 3            0.25      0.75
# 4            0.25      0.75
# 5            0.75      0.25

# %%
def distancia_entre_vetores(a, b):
    return np.linalg.norm(a - b)

# %%
def retorna_vetor_pet_db(user_id):
    data = pets_validacao
    vetor = []
    user = data.query('Id == %d' % user_id)
    for value in user.columns[:9]: ## percorre as 7 primeiras colunas
        vetor.append(user[value].values[0])
    return np.array(vetor)

# %%
def retorna_vetor_usuario(user_id):
    data = database
    vetor = []
    user = data.query('idUser == %d' % user_id)
    for value in user.columns[:7]: ## percorre as 7 primeiras colunas
        vetor.append(user[value].values[0])
    return np.array(vetor)

# %%
def retorna_vetor_pet(user_id):
    data = database
    vetor = []
    user = data.query('idUser == %d' % user_id)
    for value in user.columns[7:]: ## percorre as 7 primeiras colunas
        vetor.append(user[value].values[0])
    return np.array(vetor)

# %%
def distancia_entre_usuarios(user_id1, user_id2):
    distancia = distancia_entre_vetores(user_id1, user_id2)
    return [user_id1, user_id2, distancia]

# %%
def distancia_entre_pets(user_id1, user_id2):
    distancia = distancia_entre_vetores(retorna_vetor_pet(user_id1), retorna_vetor_pet(user_id2))
    return [user_id1, user_id2, distancia]

# %%
def distancia_de_todos_user(user_id, numero_de_usuarios_a_analisar = None):
    data = database
    todos_os_usuarios = data.index.unique()
    if numero_de_usuarios_a_analisar:
        todos_os_usuarios = todos_os_usuarios[:numero_de_usuarios_a_analisar]
    distancias = []
    for usuario in todos_os_usuarios:
        distancias.append([user_id, usuario, 
                           distancia_entre_usuarios(user_id, retorna_vetor_usuario(usuario))[2]])
    distancias = pd.DataFrame(distancias, columns = ['voce', 'outra_pessoa', 'distancia'])
    return(distancias)

# %%
def distancia_de_todos_pet(user_id, numero_de_usuarios_a_analisar = None):
    data = database
    todos_os_usuarios = data.index.unique()
    if numero_de_usuarios_a_analisar:
        data = data[:numero_de_usuarios_a_analisar]
    distancias = []
    for usuario in todos_os_usuarios:
        distancias.append([user_id, usuario, 
                           distancia_entre_pets(user_id, usuario)[2]])
    distancias = pd.DataFrame(distancias, columns = ['seu pet', 'outro_pet', 'distancia'])
    return(distancias)

# %%
def distancia_de_todos_pet_db(pet_ideal, numero_de_usuarios_a_analisar = None):
    data = database
    if numero_de_usuarios_a_analisar:
        data = data[:numero_de_usuarios_a_analisar]
    distancias = []
    for pet in data:
        pet_vetor = retorna_vetor_pet_db(pet)
        if len(pet_vetor) == 9:
            distancias.append([pet, distancia_entre_pets(pet_ideal, pet_vetor)[2]])
    distancias = pd.DataFrame(distancias, columns = ['outro_pet', 'distancia'])
    return(distancias)

# %%
def knn_user(user_id, k_mais_proximos=10, numero_de_usuarios_a_analisar = None):
    distancias = distancia_de_todos_user(user_id, numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
    distancias = distancias.sort_values("distancia")
    distancias = distancias.set_index("outra_pessoa")
    return distancias.head(k_mais_proximos)

# %%
def knn_pet(user_id, k_mais_proximos=2, numero_de_usuarios_a_analisar = None):
    distancias = distancia_de_todos_pet(user_id, numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
    distancias = distancias.sort_values("distancia")
    distancias = distancias.set_index("outro_pet")
    distancias = distancias.drop(user_id)
    return distancias.head(k_mais_proximos)

# %%
def load_data():
    data = pd.read_excel(path_database)
    
    return data

# %%
def caracteristicas_usuario(user_id):
    data = load_data()
    usuario = [data.values[user_id - 1][:7]]
    usuario = pd.DataFrame(usuario, columns=['Idade', 'Teve outro pet', 'Moradia', 'Crianças até 12 anos',
                                     'Recursos financeiros', 'Estilo de vida', 'Tempo em casa'])
    return usuario

# %%
def caracteristicas_pets(user_id):
    data = load_data()
    pet = [data.values[user - 1][7:16] for user in user_id]
    pet = pd.DataFrame(pet, columns=['Idade', 'Nivel energia', 'Tamanho', 'Necessidade de estimulo',
                                     'Temperamento', 'Comportamento com crianca', 'Comportamento com animais',
                                     'Necessidades especiais', 'Solta muito pelo'])
    pet['idUser'] = user_id
    pet = pet.set_index('idUser')
    return pet

# %%
def return_validation_array(users):
    D = [0 for n in users[0]]
    for user in users:
        for n in range(len(user)):
            D[n] += user[n]/len(users)
    
    return D

# %%
def return_recommended_pets(user_id, k_users = 10, k_pets = 2):
    users_list = knn_user(user_id, k_mais_proximos=k_users).index
    recommended_pets = []
    for user in users_list:
        knn_pets = knn_pet(user, k_mais_proximos=k_pets).index.values
        for pet in knn_pets:
            recommended_pets.append(pet)
    try:
        recommended_pets.remove(user_id)
        return recommended_pets
    except:
        return recommended_pets

# %%
def return_recommended_pets_table(recommended_pets):
    recommended_pets_arrays = [retorna_vetor_pet(pet) for pet in recommended_pets]
    validation_array = return_validation_array(recommended_pets_arrays)

    distances = [[]]
    for pet in recommended_pets:
        distances.append([pet, distancia_entre_vetores(validation_array, retorna_vetor_pet(pet))])

    recommended_pets_distances = pd.DataFrame(distances, columns=['pet_recomendado', 'distancia_pet_recomendado'])
    recommended_pets_distances = recommended_pets_distances.set_index('pet_recomendado')
    recommended_pets_table = recommended_pets_distances.join(caracteristicas_pets(recommended_pets)).dropna()
    recommended_pets_table = recommended_pets_table.sort_values('distancia_pet_recomendado')
    return recommended_pets_table

# %% [markdown]
# O usuário virá como um vetor de 7 valores

# %%
user_id = 2
user = retorna_vetor_usuario(user_id)

caracteristicas_usuario(user_id)
# Out:
#         Idade Teve outro pet      Moradia Crianças até 12 anos  \
# 0  18-25 anos            Sim  Apartamento                  Não
#
#                      Recursos financeiros  \
# 0  Confortável, sem problemas financeiros
#
#                                   Estilo de vida Tempo em casa
# 0  Gosto de ficar em casa a maior parte do tempo     4-8 horas

# %%
recommended_pets = return_recommended_pets(user, 10, 2)
print(recommended_pets)
# Out:
# [np.int64(6), np.int64(16), np.int64(7), np.int64(12), np.int64(8), np.int64(13), np.int64(9), np.int64(14), np.int64(57), np.int64(3), np.int64(30), np.int64(45), np.int64(56), np.int64(1), np.int64(5), np.int64(10), np.int64(3), np.int64(8), np.int64(4), np.int64(9)]

# %%
return_recommended_pets_table(recommended_pets)
# Out:
#                  distancia_pet_recomendado                Idade Nivel energia  \
# pet_recomendado
# 12.0                              0.291590  Filhote (até 1 ano)          Alto
# 7.0                               0.291590  Filhote (até 1 ano)          Alto
# 8.0                               0.857336  Filhote (até 1 ano)          Alto
# 8.0                               0.857336  Filhote (até 1 ano)          Alto
# 13.0                              0.857336  Filhote (até 1 ano)          Alto
# 3.0                               0.857336  Filhote (até 1 ano)          Alto
# 3.0                               0.857336  Filhote (até 1 ano)          Alto
# 3.0                               0.857336  Filhote (até 1 ano)          Alto
# 3.0                               0.857336  Filhote (até 1 ano)          Alto
# 8.0                               0.857336  Filhote (até 1 ano)          Alto
# 8.0                               0.857336  Filhote (até 1 ano)          Alto
# 1.0                               0.900014  Filhote (até 1 ano)          Alto
# 6.0                               0.900014  Filhote (até 1 ano)          Alto
# 16.0                              0.900014  Filhote (até 1 ano)          Alto
# 5.0                               0.909959   Jovem (1 - 3 anos)          Alto
# 10.0                              0.909959   Jovem (1 - 3 anos)          Alto
# 56.0                              0.963341   Jovem (1 - 3 anos)          Alto
# 57.0                              1.062085   Jovem (1 - 3 anos)          Alto
# 9.0                               1.108163   Jovem (1 - 3 anos)          Alto
# 9.0                               1.108163   Jovem (1 - 3 anos)          Alto
# 9.0                               1.108163   Jovem (1 - 3 anos)          Alto
# 9.0                               1.108163   Jovem (1 - 3 anos)          Alto
# 14.0                              1.108163   Jovem (1 - 3 anos)          Alto
# 4.0                               1.108163   Jovem (1 - 3 anos)          Alto
# 45.0                              1.197925  Filhote (até 1 ano)          Alto
# 30.0                              1.197925  Filhote (até 1 ano)          Alto
#
#                  Tamanho Necessidade de estimulo              Temperamento  \
# pet_recomendado
# 12.0               Médio                Moderada  Muito amigável com todos
# 7.0                Médio                Moderada  Muito amigável com todos
# 8.0               Grande                    Alta  Muito amigável com todos
# 8.0               Grande                    Alta  Muito amigável com todos
# 13.0              Grande                    Alta  Muito amigável com todos
# 3.0               Grande                    Alta  Muito amigável com todos
# 3.0               Grande                    Alta  Muito amigável com todos
# 3.0               Grande                    Alta  Muito amigável com todos
# 3.0               Grande                    Alta  Muito amigável com todos
# 8.0               Grande                    Alta  Muito amigável com todos
# 8.0               Grande                    Alta  Muito amigável com todos
# 1.0              Pequeno                Moderada  Muito amigável com todos
# 6.0              Pequeno                Moderada  Muito amigável com todos
# 16.0             Pequeno                Moderada  Muito amigável com todos
# 5.0                Médio                   Baixa  Muito amigável com todos
# 10.0               Médio                   Baixa  Muito amigável com todos
# 56.0             Pequeno                Moderada      Tímido, mas amigável
# 57.0              Grande                    Alta      Tímido, mas amigável
# 9.0                Médio                Moderada      Tímido, mas amigável
# 9.0                Médio                Moderada      Tímido, mas amigável
# 9.0                Médio                Moderada      Tímido, mas amigável
# 9.0                Médio                Moderada      Tímido, mas amigável
# 14.0               Médio                Moderada      Tímido, mas amigável
# 4.0                Médio                Moderada      Tímido, mas amigável
# 45.0             Pequeno                   Baixa  Muito amigável com todos
# 30.0             Pequeno                   Baixa  Muito amigável com todos
#
#                       Comportamento com crianca  \
# pet_recomendado
# 12.0                     Tolerante com crianças
# 7.0                      Tolerante com crianças
# 8.0                              Adora crianças
# 8.0                              Adora crianças
# 13.0                             Adora crianças
# 3.0                              Adora crianças
# 3.0                              Adora crianças
# 3.0                              Adora crianças
# 3.0                              Adora crianças
# 8.0                              Adora crianças
# 8.0                              Adora crianças
# 1.0                              Adora crianças
# 6.0                              Adora crianças
# 16.0                             Adora crianças
# 5.0                              Adora crianças
# 10.0                             Adora crianças
# 56.0                             Adora crianças
# 57.0                             Adora crianças
# 9.0              Prefere ambientes sem crianças
# 9.0              Prefere ambientes sem crianças
# 9.0              Prefere ambientes sem crianças
# 9.0              Prefere ambientes sem crianças
# 14.0             Prefere ambientes sem crianças
# 4.0              Prefere ambientes sem crianças
# 45.0             Prefere ambientes sem crianças
# 30.0             Prefere ambientes sem crianças
#
#                                          Comportamento com animais  \
# pet_recomendado
# 12.0             Prefere apenas a companhia de outros pets da m...
# 7.0              Prefere apenas a companhia de outros pets da m...
# 8.0                         Amigável com todos os tipos de animais
# 8.0                         Amigável com todos os tipos de animais
# 13.0                        Amigável com todos os tipos de animais
# 3.0                         Amigável com todos os tipos de animais
# 3.0                         Amigável com todos os tipos de animais
# 3.0                         Amigável com todos os tipos de animais
# 3.0                         Amigável com todos os tipos de animais
# 8.0                         Amigável com todos os tipos de animais
# 8.0                         Amigável com todos os tipos de animais
# 1.0                         Amigável com todos os tipos de animais
# 6.0                         Amigável com todos os tipos de animais
# 16.0                        Amigável com todos os tipos de animais
# 5.0                         Amigável com todos os tipos de animais
# 10.0                        Amigável com todos os tipos de animais
# 56.0                        Amigável com todos os tipos de animais
# 57.0                        Amigável com todos os tipos de animais
# 9.0                             Prefere ser o único animal da casa
# 9.0                             Prefere ser o único animal da casa
# 9.0                             Prefere ser o único animal da casa
# 9.0                             Prefere ser o único animal da casa
# 14.0                            Prefere ser o único animal da casa
# 4.0                             Prefere ser o único animal da casa
# 45.0                            Prefere ser o único animal da casa
# 30.0                            Prefere ser o único animal da casa
#
#                           Necessidades especiais  \
# pet_recomendado
# 12.0             Não, sem necessidades especiais
# 7.0              Não, sem necessidades especiais
# 8.0              Não, sem necessidades especiais
# 8.0              Não, sem necessidades especiais
# 13.0             Não, sem necessidades especiais
# 3.0              Não, sem necessidades especiais
# 3.0              Não, sem necessidades especiais
# 3.0              Não, sem necessidades especiais
# 3.0              Não, sem necessidades especiais
# 8.0              Não, sem necessidades especiais
# 8.0              Não, sem necessidades especiais
# 1.0              Não, sem necessidades especiais
# 6.0              Não, sem necessidades especiais
# 16.0             Não, sem necessidades especiais
# 5.0              Não, sem necessidades especiais
# 10.0             Não, sem necessidades especiais
# 56.0             Não, sem necessidades especiais
# 57.0             Não, sem necessidades especiais
# 9.0              Não, sem necessidades especiais
# 9.0              Não, sem necessidades especiais
# 9.0              Não, sem necessidades especiais
# 9.0              Não, sem necessidades especiais
# 14.0             Não, sem necessidades especiais
# 4.0              Não, sem necessidades especiais
# 45.0             Não, sem necessidades especiais
# 30.0             Não, sem necessidades especiais
#
#                                            Solta muito pelo
# pet_recomendado
# 12.0             Solta pelo em uma determinada época do ano
# 7.0              Solta pelo em uma determinada época do ano
# 8.0              Solta pelo em uma determinada época do ano
# 8.0              Solta pelo em uma determinada época do ano
# 13.0             Solta pelo em uma determinada época do ano
# 3.0              Solta pelo em uma determinada época do ano
# 3.0              Solta pelo em uma determinada época do ano
# 3.0              Solta pelo em uma determinada época do ano
# 3.0              Solta pelo em uma determinada época do ano
# 8.0              Solta pelo em uma determinada época do ano
# 8.0              Solta pelo em uma determinada época do ano
# 1.0                                        Solta pouco pelo
# 6.0                                        Solta pouco pelo
# 16.0                                       Solta pouco pelo
# 5.0                                        Solta muito pelo
# 10.0                                       Solta muito pelo
# 56.0                                       Solta pouco pelo
# 57.0                                       Solta pouco pelo
# 9.0                                        Solta muito pelo
# 9.0                                        Solta muito pelo
# 9.0                                        Solta muito pelo
# 9.0                                        Solta muito pelo
# 14.0                                       Solta muito pelo
# 4.0                                        Solta muito pelo
# 45.0             Solta pelo em uma determinada época do ano
# 30.0             Solta pelo em uma determinada época do ano

# %% [markdown]
# ## Para a call com stakeholders

# %% [markdown]
# # Setando as variáveis

# %%
# O Id é a Linha em que o Pet se encontra menos o valor 1
ids_pets = [100, 28, 179, 144, 180] # user_ids = 2, 102, 103, 151, 141
# ids_pets = [100, 28, 179, 144, 180] # user_ids = 101, 102, 103, 159, 124
# ids_pets = [84, 85, 86, 87, 88] # user_ids = 84, 85, 86, 87, 88
# ids_pets = [49, 50, 52, 132, 46] # user_ids = 5, 21, 51, 52, 53
user_id = 36
k_users = [10]
k_pets_por_user = [2]


pets_validacao = pets_validacao.loc[ids_pets]

# %% [markdown]
# # Visualizando os Pets e Usuários

# %%
caracteristicas_usuario(user_id)
# Out:
#         Idade Teve outro pet      Moradia Crianças até 12 anos  \
# 0  36-45 anos            Não  Apartamento                  Sim
#
#                    Recursos financeiros  \
# 0  Posso arcar com os custos essenciais
#
#                                       Estilo de vida Tempo em casa
# 0  Moderadamente ativo(a), às vezes pratico ativi...     4-8 horas

# %%
# caracteristicas_pets(ids_pets)

# %% [markdown]
# # Rodando o algoritmo

# %%
user = retorna_vetor_usuario(user_id)
resultado_posicoes = []

for n in k_users:
    for k in k_pets_por_user:
        recommended_pets = return_recommended_pets(user, n, k)
        recommended_pets_arrays = [retorna_vetor_pet(pet) for pet in recommended_pets]
        validation_array = return_validation_array(recommended_pets_arrays)
        resultado_posicoes.append([n, k, validation_array])

# %%
pets_validacao = pets_validacao.loc[ids_pets]

resultados_validacao = []
posicoes = []

for r in resultado_posicoes:
    resultados_validacao = []
    for id in pets_validacao.index.unique():
        resultados_validacao.append([id, distancia_entre_vetores(retorna_vetor_pet_db(id), r[2])])
    all_pets = pd.DataFrame(resultados_validacao, columns=["id", "distancia"]).sort_values("distancia").set_index("id")
    posicoes.append([r[0], r[1], 
                     all_pets.index.unique()[0], 
                     all_pets.index.unique()[1], 
                     all_pets.index.unique()[2], 
                     all_pets.index.unique()[3], 
                     all_pets.index.unique()[4],
                     all_pets.values.round(3)])    
all_pets = pd.DataFrame(posicoes, columns=["k_users", "k_pets_por_user", "Primeiro", "Segundo", "Terceiro", "Quarto", "Quinto", "Distancias"])
all_pets
# Out:
#    k_users  k_pets_por_user  Primeiro  Segundo  Terceiro  Quarto  Quinto  \
# 0       10                2       100      180       144      28     179
#
#                                       Distancias
# 0  [[1.001], [1.063], [1.643], [1.879], [1.983]]

# %%
validation_array = [validation_array]
validation_array = pd.DataFrame(validation_array, columns=["Idade", "Nivel de Energia", "Porte", "Estimulos", "Temperamento", 
                                         "Comportamento Criança", "Socializacao Animais", "Necessidade Especial", "Pelo"])
validation_array
# Out:
#    Idade  Nivel de Energia  Porte  Estimulos  Temperamento  \
# 0   0.23               0.0   0.25        0.3           0.8
#
#    Comportamento Criança  Socializacao Animais  Necessidade Especial  Pelo
# 0                    0.5                   0.7                  0.35  0.35
